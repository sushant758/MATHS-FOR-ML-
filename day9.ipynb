# %% [markdown]
# <a href="https://colab.research.google.com/github/sushant758/MATHS-FOR-ML-/blob/main/day9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PCA From Scratch

# %%
from sklearn.datasets import load_iris
import numpy as np
import pandas as pd

# %%
iris = load_iris()
X = iris.data

# %%
print(X.shape)
# Out:
# (150, 4)

# %%
X_mean = np.mean(X, axis=0)

# %%
X_centered = X - X_mean

# %%
print(X_mean)
# Out:
# [5.84333333 3.05733333 3.758      1.19933333]

# %%
cov_matrix = np.cov(X_centered.T)

# %%
print(cov_matrix.shape)
# Out:
# (4, 4)

# %%
print(cov_matrix)
# Out:
# [[ 0.68569351 -0.042434    1.27431544  0.51627069]
#  [-0.042434    0.18997942 -0.32965638 -0.12163937]
#  [ 1.27431544 -0.32965638  3.11627785  1.2956094 ]
#  [ 0.51627069 -0.12163937  1.2956094   0.58100626]]

# %%
eigenvalues, eigenvectors = np.linalg.eig(cov_matrix)

# %%
print("Eigenvalues:")
print(eigenvalues)

print("\nEigenvectors:")
print(eigenvectors)
# Out:
# Eigenvalues:
# [4.22824171 0.24267075 0.0782095  0.02383509]
#
# Eigenvectors:
# [[ 0.36138659 -0.65658877 -0.58202985  0.31548719]
#  [-0.08452251 -0.73016143  0.59791083 -0.3197231 ]
#  [ 0.85667061  0.17337266  0.07623608 -0.47983899]
#  [ 0.3582892   0.07548102  0.54583143  0.75365743]]

# %%
sorted_indices = np.argsort(eigenvalues)[::-1]

# %%
eigenvalues = eigenvalues[sorted_indices]

# %%
eigenvectors = eigenvectors[:, sorted_indices]

# %%
print(eigenvalues)
# Out:
# [4.22824171 0.24267075 0.0782095  0.02383509]

# %%
k = 2

# %%
principal_components = eigenvectors[:, :k]

# %%
print(principal_components.shape)
# Out:
# (4, 2)

# %%
X_pca = X_centered @ principal_components

# %%
print(X_pca.shape)
# Out:
# (150, 2)

# %%
explained_variance_ratio = eigenvalues / np.sum(eigenvalues)

# %%
print(explained_variance_ratio)
# Out:
# [0.92461872 0.05306648 0.01710261 0.00521218]

# %%
variance_retained = np.sum(explained_variance_ratio[:2])

# %%
print("Variance Retained:", variance_retained)
# Out:
# Variance Retained: 0.9776852063187949

# %% [markdown]
# # Compare with sklearn PCA.

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=2)

# %%
X_sklearn = pca.fit_transform(X)

# %%
print(X_sklearn.shape)
# Out:
# (150, 2)
